# %% [markdown]
# # Práctico 06 10 2021
#
# ### Estadística descriptiva en python

# %%
import numpy as np
from scipy import stats
import pandas as pd

# %%
np.random.seed(123456)

# %%
datos_normales = np.random.rand(5,4)

# %%
datos_normales
# Out:
# array([[0.12696983, 0.96671784, 0.26047601, 0.89723652],
#        [0.37674972, 0.33622174, 0.45137647, 0.84025508],
#        [0.12310214, 0.5430262 , 0.37301223, 0.44799682],
#        [0.12944068, 0.85987871, 0.82038836, 0.35205354],
#        [0.2288873 , 0.77678375, 0.59478359, 0.13755356]])

# %%
type(datos_normales)
# Out:
# numpy.ndarray

# %% [markdown]
# #### Calculamos la media aritmetica (promedio) de los valores de todo mi array

# %%
datos_normales?

# %%
datos_normales.mean()
# Out:
# 0.4821455050848534

# %%
suma=0
contador=0
for i in datos_normales:
    suma+=i
    contador+=1
    
suma=suma/contador
print(suma)
# Out:
# [0.19702994 0.69652565 0.50000733 0.53501911]

# %%
np.mean(datos_normales)
# Out:
# 0.4821455050848534

# %% [markdown]
# ###### Calculamos la media aritmetica SOLO de las columnas de mi array

# %%
promedio_columnas=datos_normales.mean(axis=0)

# %%
type(promedio_columnas)
# Out:
# numpy.ndarray

# %%
promedio_columnas
# Out:
# array([0.19702994, 0.69652565, 0.50000733, 0.53501911])

# %%
datos_normales.mean(axis=0)[0]
# Out:
# 0.1970299355110796

# %%
np.mean([0.12696983,0.37674972,0.12310214, 0.12944068,0.2288873 ])
# Out:
# 0.197029934

# %% [markdown]
# #### Calculamos la media aritmética SOLO de las filas de mi array

# %%
datos_normales.mean(axis=1)
# Out:
# array([0.56285005, 0.50115075, 0.37178435, 0.54044032, 0.43450205])

# %% [markdown]
# #### La media aritmetica de la primera fila de mi array

# %%
datos_normales.mean(axis=1)[0]
# Out:
# 0.5628500504376153

# %%
np.mean([0.12696983, 0.96671784, 0.26047601, 0.89723652])
# Out:
# 0.56285005

# %%
(0.12696983+0.96671784+0.26047601+0.89723652)/4
# Out:
# 0.56285005

# %% [markdown]
# ### Calcular la desviación típica

# %%
np.std(datos_normales)
# Out:
# 0.28022148574704847

# %%
np.std?

# %%
np.std(datos_normales,axis=0)
# Out:
# array([0.09824066, 0.22782027, 0.19364634, 0.2909978 ])

# %%
np.std(datos_normales,axis=1)
# Out:
# array([0.37294273, 0.20009149, 0.15570522, 0.31017014, 0.26139184])

# %% [markdown]
# #### Varianza

# %%
np.var(datos_normales)
# Out:
# 0.07852408107428328

# %%
np.var(datos_normales,axis=0)
# Out:
# array([0.00965123, 0.05190208, 0.0374989 , 0.08467972])

# %%
np.var(datos_normales,axis=1)
# Out:
# array([0.13908628, 0.04003661, 0.02424412, 0.09620552, 0.06832569])

# %% [markdown]
# #### Ocupando scipy stats
#
#
# ######## disclaimer= np no calcula moda, entonces lo haremos por scipy

# %%
stats.mode(datos_normales)
# Out:
# ModeResult(mode=array([[0.12310214, 0.33622174, 0.26047601, 0.13755356]]), count=array([[1, 1, 1, 1]]))

# %%
datos_custom=[[2,3,4,5],
              [2,3,4,5],
              [1,2,4,4],
              [0,0,0,1],]

# %% [markdown]
# ##### Calculamos la media de mi valores custom

# %%
np.mean(datos_custom)
# Out:
# 2.5

# %%
stats.mode(datos_custom)
# Out:
# ModeResult(mode=array([[2, 3, 4, 5]]), count=array([[2, 2, 3, 2]]))

# %% [markdown]
# #### Calculamos el coeficiente de correlación

# %%
np.corrcoef(datos_normales)
# Out:
# array([[ 1.        ,  0.38881211,  0.87252842,  0.3469062 ,  0.20541644],
#        [ 0.38881211,  1.        ,  0.22850405, -0.31973003, -0.66702592],
#        [ 0.87252842,  0.22850405,  1.        ,  0.73970137,  0.53630928],
#        [ 0.3469062 , -0.31973003,  0.73970137,  1.        ,  0.90858386],
#        [ 0.20541644, -0.66702592,  0.53630928,  0.90858386,  1.        ]])

# %%
####imc=kg/m2
imc=80/(1.76**2)

# %% [markdown]
# El imc se genera a partir del peso y la altura, por lo que agregarlo en mi matriz de datos es redundante y podría generar un sesgo (bias) a esas mediciones.

# %%
datos_pacientes=[[80,1.76,25.82],

                 [76,1.76,24.5]]

# %%
datos_normales[0]
# Out:
# array([0.12696983, 0.96671784, 0.26047601, 0.89723652])

# %% [markdown]
# ##### Calculamos la covarianza

# %%
np.cov(datos_normales[0],datos_normales[1])
# Out:
# array([[0.18544838, 0.0386856 ],
#        [0.0386856 , 0.05338214]])

# %% [markdown]
# ## Vamos a partir con PANDAS
#
# Los dataframes y las series son la unidad básica de pandas
# una serie es un vector, mientras que un dataframe es una matriz

# %%
dataframe = pd.DataFrame(datos_normales)

# %%
dataframe
# Out:
#           0         1         2         3
# 0  0.126970  0.966718  0.260476  0.897237
# 1  0.376750  0.336222  0.451376  0.840255
# 2  0.123102  0.543026  0.373012  0.447997
# 3  0.129441  0.859879  0.820388  0.352054
# 4  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.to_excel("archivo_excel.xls")
# Out:
# <ipython-input-45-595b36696e3a>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   dataframe.to_excel("archivo_excel.xls")

# %%
dataframe.rename({0:'c1', 1:'c2',2:'c3',3:'c4'},axis=1)
# Out:
#          c1        c2        c3        c4
# 0  0.126970  0.966718  0.260476  0.897237
# 1  0.376750  0.336222  0.451376  0.840255
# 2  0.123102  0.543026  0.373012  0.447997
# 3  0.129441  0.859879  0.820388  0.352054
# 4  0.228887  0.776784  0.594784  0.137554

# %%
df2=dataframe.rename({0:'c1', 1:'c2',2:'c3',3:'c4'},axis=1)

# %%
dataframe
# Out:
#           0         1         2         3
# 0  0.126970  0.966718  0.260476  0.897237
# 1  0.376750  0.336222  0.451376  0.840255
# 2  0.123102  0.543026  0.373012  0.447997
# 3  0.129441  0.859879  0.820388  0.352054
# 4  0.228887  0.776784  0.594784  0.137554

# %%
df2
# Out:
#          c1        c2        c3        c4
# 0  0.126970  0.966718  0.260476  0.897237
# 1  0.376750  0.336222  0.451376  0.840255
# 2  0.123102  0.543026  0.373012  0.447997
# 3  0.129441  0.859879  0.820388  0.352054
# 4  0.228887  0.776784  0.594784  0.137554

# %%
dataframe
# Out:
#           0         1         2         3
# 0  0.126970  0.966718  0.260476  0.897237
# 1  0.376750  0.336222  0.451376  0.840255
# 2  0.123102  0.543026  0.373012  0.447997
# 3  0.129441  0.859879  0.820388  0.352054
# 4  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.rename({0:'c1', 1:'c2',2:'c3',3:'c4'},axis=1, inplace=True)

# %%
dataframe
# Out:
#          c1        c2        c3        c4
# 0  0.126970  0.966718  0.260476  0.897237
# 1  0.376750  0.336222  0.451376  0.840255
# 2  0.123102  0.543026  0.373012  0.447997
# 3  0.129441  0.859879  0.820388  0.352054
# 4  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.rename({0:'i1', 1:'i2',2:'i3',3:'i4',4:'i5'},axis=0,inplace=True)

# %%
dataframe
# Out:
#           c1        c2        c3        c4
# i1  0.126970  0.966718  0.260476  0.897237
# i2  0.376750  0.336222  0.451376  0.840255
# i3  0.123102  0.543026  0.373012  0.447997
# i4  0.129441  0.859879  0.820388  0.352054
# i5  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.c1
# Out:
# i1    0.126970
# i2    0.376750
# i3    0.123102
# i4    0.129441
# i5    0.228887
# Name: c1, dtype: float64

# %%
dataframe['c1']
# Out:
# i1    0.126970
# i2    0.376750
# i3    0.123102
# i4    0.129441
# i5    0.228887
# Name: c1, dtype: float64

# %%
dataframe.c1
# Out:
# i1    0.126970
# i2    0.376750
# i3    0.123102
# i4    0.129441
# i5    0.228887
# Name: c1, dtype: float64

# %%
dataframe.head(3)
# Out:
#           c1        c2        c3        c4
# i1  0.126970  0.966718  0.260476  0.897237
# i2  0.376750  0.336222  0.451376  0.840255
# i3  0.123102  0.543026  0.373012  0.447997

# %%
dataframe.tail(2)
# Out:
#           c1        c2        c3        c4
# i4  0.129441  0.859879  0.820388  0.352054
# i5  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.describe()
# Out:
#              c1        c2        c3        c4
# count  5.000000  5.000000  5.000000  5.000000
# mean   0.197030  0.696526  0.500007  0.535019
# std    0.109836  0.254711  0.216503  0.325345
# min    0.123102  0.336222  0.260476  0.137554
# 25%    0.126970  0.543026  0.373012  0.352054
# 50%    0.129441  0.776784  0.451376  0.447997
# 75%    0.228887  0.859879  0.594784  0.840255
# max    0.376750  0.966718  0.820388  0.897237

# %%
df2=dataframe.rename({'c1':'columna 1', 'c2':'columna 2','c3':'columna 3','c4':'columna 4'},axis=1, inplace=False)

# %%
df2
# Out:
#     columna 1  columna 2  columna 3  columna 4
# i1   0.126970   0.966718   0.260476   0.897237
# i2   0.376750   0.336222   0.451376   0.840255
# i3   0.123102   0.543026   0.373012   0.447997
# i4   0.129441   0.859879   0.820388   0.352054
# i5   0.228887   0.776784   0.594784   0.137554

# %%
dataframe
# Out:
#           c1        c2        c3        c4
# i1  0.126970  0.966718  0.260476  0.897237
# i2  0.376750  0.336222  0.451376  0.840255
# i3  0.123102  0.543026  0.373012  0.447997
# i4  0.129441  0.859879  0.820388  0.352054
# i5  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.sum()
# Out:
# c1    0.985150
# c2    3.482628
# c3    2.500037
# c4    2.675096
# dtype: float64

# %%
dataframe.sum(axis=0)
# Out:
# c1    0.985150
# c2    3.482628
# c3    2.500037
# c4    2.675096
# dtype: float64

# %%
dataframe.sum(axis=1)
# Out:
# i1    2.251400
# i2    2.004603
# i3    1.487137
# i4    2.161761
# i5    1.738008
# dtype: float64

# %%
dataframe.cumsum()
# Out:
#           c1        c2        c3        c4
# i1  0.126970  0.966718  0.260476  0.897237
# i2  0.503720  1.302940  0.711852  1.737492
# i3  0.626822  1.845966  1.084865  2.185488
# i4  0.756262  2.705844  1.905253  2.537542
# i5  0.985150  3.482628  2.500037  2.675096

# %%
dataframe.cumsum(axis=1)
# Out:
#           c1        c2        c3        c4
# i1  0.126970  1.093688  1.354164  2.251400
# i2  0.376750  0.712971  1.164348  2.004603
# i3  0.123102  0.666128  1.039141  1.487137
# i4  0.129441  0.989319  1.809708  2.161761
# i5  0.228887  1.005671  1.600455  1.738008

# %%
dataframe
# Out:
#           c1        c2        c3        c4
# i1  0.126970  0.966718  0.260476  0.897237
# i2  0.376750  0.336222  0.451376  0.840255
# i3  0.123102  0.543026  0.373012  0.447997
# i4  0.129441  0.859879  0.820388  0.352054
# i5  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.mean()
# Out:
# c1    0.197030
# c2    0.696526
# c3    0.500007
# c4    0.535019
# dtype: float64

# %%
dataframe.mean(axis=1)
# Out:
# i1    0.562850
# i2    0.501151
# i3    0.371784
# i4    0.540440
# i5    0.434502
# dtype: float64

# %%
dataframe.mode()
# Out:
#          c1        c2        c3        c4
# 0  0.123102  0.336222  0.260476  0.137554
# 1  0.126970  0.543026  0.373012  0.352054
# 2  0.129441  0.776784  0.451376  0.447997
# 3  0.228887  0.859879  0.594784  0.840255
# 4  0.376750  0.966718  0.820388  0.897237

# %%
dataframe
# Out:
#           c1        c2        c3        c4
# i1  0.126970  0.966718  0.260476  0.897237
# i2  0.376750  0.336222  0.451376  0.840255
# i3  0.123102  0.543026  0.373012  0.447997
# i4  0.129441  0.859879  0.820388  0.352054
# i5  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.T
# Out:
#           i1        i2        i3        i4        i5
# c1  0.126970  0.376750  0.123102  0.129441  0.228887
# c2  0.966718  0.336222  0.543026  0.859879  0.776784
# c3  0.260476  0.451376  0.373012  0.820388  0.594784
# c4  0.897237  0.840255  0.447997  0.352054  0.137554

# %%
dataframe
# Out:
#           c1        c2        c3        c4
# i1  0.126970  0.966718  0.260476  0.897237
# i2  0.376750  0.336222  0.451376  0.840255
# i3  0.123102  0.543026  0.373012  0.447997
# i4  0.129441  0.859879  0.820388  0.352054
# i5  0.228887  0.776784  0.594784  0.137554

# %%
dfT=dataframe.T

# %%
dfT
# Out:
#           i1        i2        i3        i4        i5
# c1  0.126970  0.376750  0.123102  0.129441  0.228887
# c2  0.966718  0.336222  0.543026  0.859879  0.776784
# c3  0.260476  0.451376  0.373012  0.820388  0.594784
# c4  0.897237  0.840255  0.447997  0.352054  0.137554

# %%
dataframe.plot()
# Out:
# <AxesSubplot:>

# %%
dataframe
# Out:
#           c1        c2        c3        c4
# i1  0.126970  0.966718  0.260476  0.897237
# i2  0.376750  0.336222  0.451376  0.840255
# i3  0.123102  0.543026  0.373012  0.447997
# i4  0.129441  0.859879  0.820388  0.352054
# i5  0.228887  0.776784  0.594784  0.137554

# %%
dataframe.plot?

# %%
dataframe.hist()
# Out:
# array([[<AxesSubplot:title={'center':'c1'}>,
#         <AxesSubplot:title={'center':'c2'}>],
#        [<AxesSubplot:title={'center':'c3'}>,
#         <AxesSubplot:title={'center':'c4'}>]], dtype=object)

# %%
dataframe.hist('c1')
# Out:
# array([[<AxesSubplot:title={'center':'c1'}>]], dtype=object)

# %%
columnas=dataframe.columns

# %%
columnas
# Out:
# Index(['c1', 'c2', 'c3', 'c4'], dtype='object')

# %%
dataframe.hist?

# %%
dataframe.hist()

# %%
for columna in columnas:
    dataframe.hist(column=columna,grid=False)

# %%
df=pd.DataFrame(datos_pacientes,columns=['peso','altura','imc'],index=['paciente1','paciente2'])

# %%
df
# Out:
#            peso  altura    imc
# paciente1    80    1.76  25.82
# paciente2    76    1.76  24.50

# %%
df.dtypes
# Out:
# peso        int64
# altura    float64
# imc       float64
# dtype: object

# %%
df.describe()
# Out:
#             peso  altura        imc
# count   2.000000    2.00   2.000000
# mean   78.000000    1.76  25.160000
# std     2.828427    0.00   0.933381
# min    76.000000    1.76  24.500000
# 25%    77.000000    1.76  24.830000
# 50%    78.000000    1.76  25.160000
# 75%    79.000000    1.76  25.490000
# max    80.000000    1.76  25.820000

# %%
censo = pd.read_csv('data/censo.csv',sep=",",index_col=0)

# %%
censo
# Out:
#                               NOMBRE REGIÓN Código Región  NOMBRE PROVINCIA  \
# ORDEN
# 0                                      PAÍS          PAÍS              PAÍS
# 1                                      PAÍS          PAÍS              PAÍS
# 2                                      PAÍS          PAÍS              PAÍS
# 3                                      PAÍS          PAÍS              PAÍS
# 4                                      PAÍS          PAÍS              PAÍS
# ...                                     ...           ...               ...
# 7629   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7630   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7631   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7632   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7633   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
#
# ...

# %%
censo = pd.read_excel('data/censo.xlsx',index_col=0)

# %%
censo
# Out:
#                               NOMBRE REGIÓN Código Región  NOMBRE PROVINCIA  \
# ORDEN
# 0                                      PAÍS          PAÍS              PAÍS
# 1                                      PAÍS          PAÍS              PAÍS
# 2                                      PAÍS          PAÍS              PAÍS
# 3                                      PAÍS          PAÍS              PAÍS
# 4                                      PAÍS          PAÍS              PAÍS
# ...                                     ...           ...               ...
# 7629   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7630   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7631   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7632   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7633   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
#
# ...

# %%
censo.dtypes
# Out:
# NOMBRE REGIÓN       object
# Código Región       object
# NOMBRE PROVINCIA    object
# Código Provincia    object
# NOMBRE COMUNA       object
# Código Comuna       object
# Edad                object
# Hombres              int64
# Mujeres              int64
# TOTAL                int64
# dtype: object

# %%
censo.describe()
# Out:
#             Hombres       Mujeres         TOTAL
# count  7.634000e+03  7.634000e+03  7.634000e+03
# mean   4.507199e+03  4.701081e+03  9.208280e+03
# std    1.020434e+05  1.062896e+05  2.083241e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.162500e+02  1.240000e+02  2.450000e+02
# 50%    4.130000e+02  4.205000e+02  8.355000e+02
# 75%    1.246000e+03  1.324750e+03  2.564750e+03
# max    8.601989e+06  8.972014e+06  1.757400e+07

# %%
censo.dtypes
# Out:
# NOMBRE REGIÓN       object
# Código Región       object
# NOMBRE PROVINCIA    object
# Código Provincia    object
# NOMBRE COMUNA       object
# Código Comuna       object
# Edad                object
# Hombres              int64
# Mujeres              int64
# TOTAL                int64
# dtype: object

# %%
magallanes=censo[censo['NOMBRE REGIÓN']=='MAGALLANES Y DE LA ANTÁRTICA CHILENA']

# %%
censo['NOMBRE REGIÓN']=='MAGALLANES Y DE LA ANTÁRTICA CHILENA'
# Out:
# ORDEN
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7629     True
# 7630     True
# 7631     True
# 7632     True
# 7633     True
# Name: NOMBRE REGIÓN, Length: 7634, dtype: bool

# %%
magallanes=censo[censo['NOMBRE REGIÓN']=='MAGALLANES Y DE LA ANTÁRTICA CHILENA']

# %%
magallanes[magallanes.Edad=='0 a 4']
# Out:
#                               NOMBRE REGIÓN Código Región   NOMBRE PROVINCIA  \
# ORDEN
# 7393   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12         MAGALLANES
# 7415   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12         MAGALLANES
# 7437   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12         MAGALLANES
# 7459   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12         MAGALLANES
# 7481   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ANTÁRTICA CHILENA
# 7503   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ANTÁRTICA CHILENA
# 7525   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12   TIERRA DEL FUEGO
# 7547   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12   TIERRA DEL FUEGO
# 7569   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12   TIERRA DEL FUEGO
# 7591   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12   ÚLTIMA ESPERANZA
# 7613   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12   ÚLTIMA ESPERANZA
#
# ...

# %%
punta_arenas=censo[censo['NOMBRE COMUNA']=='PUNTA ARENAS']

# %%
punta_arenas
# Out:
#                               NOMBRE REGIÓN Código Región NOMBRE PROVINCIA  \
# ORDEN
# 7392   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7393   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7394   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7395   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7396   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7397   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7398   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7399   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7400   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7401   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7402   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# ...

# %%
punta_arenas=magallanes[magallanes['NOMBRE COMUNA']=='PUNTA ARENAS']

# %%
punta_arenas.shape
# Out:
# (22, 10)

# %%
magallanes.head(25)
# Out:
#                               NOMBRE REGIÓN Código Región NOMBRE PROVINCIA  \
# ORDEN
# 7392   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7393   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7394   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7395   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7396   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7397   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7398   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7399   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7400   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7401   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# 7402   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12       MAGALLANES
# ...

# %%
censo.shape
# Out:
# (7634, 10)

# %%
magallanes.shape
# Out:
# (242, 10)

# %%
censo[censo.Edad =='Total Comunal']
# Out:
#                               NOMBRE REGIÓN Código Región  NOMBRE PROVINCIA  \
# ORDEN
# 22                       ARICA Y PARINACOTA            15             ARICA
# 44                       ARICA Y PARINACOTA            15             ARICA
# 66                       ARICA Y PARINACOTA            15        PARINACOTA
# 88                       ARICA Y PARINACOTA            15        PARINACOTA
# 110                                TARAPACÁ             1           IQUIQUE
# ...                                     ...           ...               ...
# 7524   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  TIERRA DEL FUEGO
# 7546   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  TIERRA DEL FUEGO
# 7568   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  TIERRA DEL FUEGO
# 7590   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7612   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
#
# ...

# %%
filtro=censo[censo.Edad  != 'Total Comunal']

# %%
filtro
# Out:
#                               NOMBRE REGIÓN Código Región  NOMBRE PROVINCIA  \
# ORDEN
# 0                                      PAÍS          PAÍS              PAÍS
# 1                                      PAÍS          PAÍS              PAÍS
# 2                                      PAÍS          PAÍS              PAÍS
# 3                                      PAÍS          PAÍS              PAÍS
# 4                                      PAÍS          PAÍS              PAÍS
# ...                                     ...           ...               ...
# 7629   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7630   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7631   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7632   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7633   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
#
# ...

# %%
filtro=filtro[filtro['NOMBRE REGIÓN']!='PAÍS']

# %%
filtro
# Out:
#                               NOMBRE REGIÓN Código Región  NOMBRE PROVINCIA  \
# ORDEN
# 23                       ARICA Y PARINACOTA            15             ARICA
# 24                       ARICA Y PARINACOTA            15             ARICA
# 25                       ARICA Y PARINACOTA            15             ARICA
# 26                       ARICA Y PARINACOTA            15             ARICA
# 27                       ARICA Y PARINACOTA            15             ARICA
# ...                                     ...           ...               ...
# 7629   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7630   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7631   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7632   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7633   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
#
# ...

# %%
filtro['NOMBRE REGIÓN'].unique()
# Out:
# array(['ARICA Y PARINACOTA', 'TARAPACÁ', 'ANTOFAGASTA', 'ATACAMA',
#        'COQUIMBO', 'VALPARAÍSO', 'METROPOLITANA DE SANTIAGO',
#        "LIBERTADOR GENERAL BERNARDO O'HIGGINS", 'MAULE', 'BIOBÍO',
#        'LA ARAUCANÍA', 'LOS RÍOS', 'LOS LAGOS',
#        'AYSÉN DEL GENERAL CARLOS IBÁÑEZ DEL CAMPO',
#        'MAGALLANES Y DE LA ANTÁRTICA CHILENA'], dtype=object)

# %%
filtro['Hombres'][filtro['NOMBRE REGIÓN']=='COQUIMBO']
# Out:
# ORDEN
# 661    7923
# 662    8285
# 663    7722
# 664    9140
# 665    9846
#        ...
# 985      37
# 986      36
# 987      13
# 988       7
# 989       1
# Name: Hombres, Length: 315, dtype: int64

# %%
totales_comunales=censo[censo.Edad=='Total Comunal']

# %%
totales_comunales
# Out:
#                               NOMBRE REGIÓN Código Región  NOMBRE PROVINCIA  \
# ORDEN
# 22                       ARICA Y PARINACOTA            15             ARICA
# 44                       ARICA Y PARINACOTA            15             ARICA
# 66                       ARICA Y PARINACOTA            15        PARINACOTA
# 88                       ARICA Y PARINACOTA            15        PARINACOTA
# 110                                TARAPACÁ             1           IQUIQUE
# ...                                     ...           ...               ...
# 7524   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  TIERRA DEL FUEGO
# 7546   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  TIERRA DEL FUEGO
# 7568   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  TIERRA DEL FUEGO
# 7590   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7612   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
#
# ...

# %%
totales_comunales['NOMBRE REGIÓN'].unique()
# Out:
# array(['ARICA Y PARINACOTA', 'TARAPACÁ', 'ANTOFAGASTA', 'ATACAMA',
#        'COQUIMBO', 'VALPARAÍSO', 'METROPOLITANA DE SANTIAGO',
#        "LIBERTADOR GENERAL BERNARDO O'HIGGINS", 'MAULE', 'BIOBÍO',
#        'LA ARAUCANÍA', 'LOS RÍOS', 'LOS LAGOS',
#        'AYSÉN DEL GENERAL CARLOS IBÁÑEZ DEL CAMPO',
#        'MAGALLANES Y DE LA ANTÁRTICA CHILENA'], dtype=object)

# %%
filtro.plot?

# %%
err=pd.read_csv('data/censo_err.csv',index_col=0)

# %%
err.dtypes
# Out:
# NOMBRE REGIÓN       object
# Código Región       object
# NOMBRE PROVINCIA    object
# Código Provincia    object
# NOMBRE COMUNA       object
# Código Comuna       object
# Edad                object
# Hombres             object
# Mujeres              int64
# TOTAL                int64
# dtype: object

# %%
err.describe()
# Out:
#             Mujeres         TOTAL
# count  7.634000e+03  7.634000e+03
# mean   4.701081e+03  9.208280e+03
# std    1.062896e+05  2.083241e+05
# min    0.000000e+00  0.000000e+00
# 25%    1.240000e+02  2.450000e+02
# 50%    4.205000e+02  8.355000e+02
# 75%    1.324750e+03  2.564750e+03
# max    8.972014e+06  1.757400e+07

# %%
err['Hombres']
# Out:
# ORDEN
# 0       '8601989'
# 1          594059
# 2          618121
# 3          585855
# 4          636064
#           ...
# 7629            2
# 7630            0
# 7631            0
# 7632            0
# 7633            0
# Name: Hombres, Length: 7634, dtype: object

# %%
pd.to_numeric(err['Hombres'], errors="coerce" )
# Out:
# ORDEN
# 0            NaN
# 1       594059.0
# 2       618121.0
# 3       585855.0
# 4       636064.0
#           ...
# 7629         2.0
# 7630         0.0
# 7631         0.0
# 7632         0.0
# 7633         0.0
# Name: Hombres, Length: 7634, dtype: float64

# %%
no_en_pais=filtro[filtro['NOMBRE REGIÓN']!='PAÍS']

# %%
no_en_pais.groupby('NOMBRE REGIÓN')['Hombres'].count()
# Out:
# NOMBRE REGIÓN
# ANTOFAGASTA                                   189
# ARICA Y PARINACOTA                             84
# ATACAMA                                       189
# AYSÉN DEL GENERAL CARLOS IBÁÑEZ DEL CAMPO     210
# BIOBÍO                                       1134
# COQUIMBO                                      315
# LA ARAUCANÍA                                  672
# LIBERTADOR GENERAL BERNARDO O'HIGGINS         693
# LOS LAGOS                                     630
# LOS RÍOS                                      252
# MAGALLANES Y DE LA ANTÁRTICA CHILENA          231
# MAULE                                         630
# METROPOLITANA DE SANTIAGO                    1092
# TARAPACÁ                                      147
# VALPARAÍSO                                    798
# Name: Hombres, dtype: int64

# %%
no_en_pais
# Out:
#                               NOMBRE REGIÓN Código Región  NOMBRE PROVINCIA  \
# ORDEN
# 23                       ARICA Y PARINACOTA            15             ARICA
# 24                       ARICA Y PARINACOTA            15             ARICA
# 25                       ARICA Y PARINACOTA            15             ARICA
# 26                       ARICA Y PARINACOTA            15             ARICA
# 27                       ARICA Y PARINACOTA            15             ARICA
# ...                                     ...           ...               ...
# 7629   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7630   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7631   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7632   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
# 7633   MAGALLANES Y DE LA ANTÁRTICA CHILENA            12  ÚLTIMA ESPERANZA
#
# ...
