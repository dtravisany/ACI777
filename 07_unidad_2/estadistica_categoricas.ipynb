# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.float_format='{:,.2f}'.format
pd.set_option('display.max_rows',20)

# %%
nls97 = pd.read_csv("data/nls97.csv")

# %%
#### SPLICE AND DICE

# %%
nls97.head()
# Out:
#    personid  gender  birthmonth  birthyear  highestgradecompleted  \
# 0    100061  Female           5       1980                  13.00
# 1    100139    Male           9       1983                  12.00
# 2    100284    Male          11       1984                   7.00
# 3    100292    Male           4       1982                    NaN
# 4    100583    Male           1       1980                  13.00
#
#    maritalstatus  childathome  childnotathome  wageincome  \
# 0        Married         4.00            0.00   12,500.00
# 1        Married         2.00            0.00  120,000.00
# 2  Never-married         1.00            0.00   58,000.00
# 3            NaN          NaN             NaN         NaN
# 4        Married         4.00            0.00   30,000.00
#
#          weeklyhrscomputer  ...      colenrfeb13      colenroct13  \
# 0  10 hours or more a week  ...  1. Not enrolled  1. Not enrolled
# 1      1 to 3 hours a week  ...  1. Not enrolled  1. Not enrolled
# 2                     None  ...  1. Not enrolled  1. Not enrolled
# 3                      NaN  ...  1. Not enrolled  1. Not enrolled
# 4  Less than 1 hour a week  ...  1. Not enrolled  1. Not enrolled
#
#        colenrfeb14      colenroct14      colenrfeb15      colenroct15  \
# 0  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 1  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 2  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 3  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 4  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
#
#        colenrfeb16      colenroct16      colenrfeb17      colenroct17
# 0  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 1  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 2  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 3              NaN              NaN              NaN              NaN
# 4  1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
#
# [5 rows x 89 columns]

# %%
nls97.set_index("personid", inplace=True)

# %%
nls97.head()
# Out:
#           gender  birthmonth  birthyear  highestgradecompleted  maritalstatus  \
# personid
# 100061    Female           5       1980                  13.00        Married
# 100139      Male           9       1983                  12.00        Married
# 100284      Male          11       1984                   7.00  Never-married
# 100292      Male           4       1982                    NaN            NaN
# 100583      Male           1       1980                  13.00        Married
#
#           childathome  childnotathome  wageincome        weeklyhrscomputer  \
# personid
# 100061           4.00            0.00   12,500.00  10 hours or more a week
# 100139           2.00            0.00  120,000.00      1 to 3 hours a week
# 100284           1.00            0.00   58,000.00                     None
# 100292            NaN             NaN         NaN                      NaN
# 100583           4.00            0.00   30,000.00  Less than 1 hour a week
#
#                     weeklyhrstv  ...      colenrfeb13      colenroct13  \
# personid                         ...
# 100061    11 to 20 hours a week  ...  1. Not enrolled  1. Not enrolled
# 100139     3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
# 100284    11 to 20 hours a week  ...  1. Not enrolled  1. Not enrolled
# 100292                      NaN  ...  1. Not enrolled  1. Not enrolled
# 100583     3 to 10 hours a week  ...  1. Not enrolled  1. Not enrolled
#
#               colenrfeb14      colenroct14      colenrfeb15      colenroct15  \
# personid
# 100061    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100139    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100284    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100292    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100583    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
#
#               colenrfeb16      colenroct16      colenrfeb17      colenroct17
# personid
# 100061    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100139    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100284    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
# 100292                NaN              NaN              NaN              NaN
# 100583    1. Not enrolled  1. Not enrolled  1. Not enrolled  1. Not enrolled
#
# [5 rows x 88 columns]

# %%
nls97.dtypes
# Out:
# gender                    object
# birthmonth                 int64
# birthyear                  int64
# highestgradecompleted    float64
# maritalstatus             object
#                           ...
# colenroct15               object
# colenrfeb16               object
# colenroct16               object
# colenrfeb17               object
# colenroct17               object
# Length: 88, dtype: object

# %% [markdown]
# #### Tarea Identificar / explicar que es la función lambda en python y sus aplicaciones

# %%
nls97.loc[:,nls97.dtypes=='object'] = nls97.select_dtypes(['object']).apply(lambda x:x.astype('category'))

# %% [markdown]
# En cada categoria(variable) vamos a ver cuantas observaciones (filas, personas_no_responden) estan vacias.

# %%
catcols = nls97.select_dtypes(include=["category"]).columns
nls97[catcols].isnull().sum()
# Out:
# gender                  0
# maritalstatus        2312
# weeklyhrscomputer    2274
# weeklyhrstv          2273
# highestdegree          31
#                      ...
# colenroct15          1515
# colenrfeb16          1948
# colenroct16          2251
# colenrfeb17          2251
# colenroct17          2250
# Length: 57, dtype: int64

# %%
nls97.maritalstatus.value_counts()
# Out:
# Married          3066
# Never-married    2766
# Divorced          663
# Separated         154
# Widowed            23
# Name: maritalstatus, dtype: int64

# %%
nls97.maritalstatus.value_counts(sort=False)
# Out:
# Divorced          663
# Married          3066
# Never-married    2766
# Separated         154
# Widowed            23
# Name: maritalstatus, dtype: int64

# %%
nls97.maritalstatus.value_counts(sort=False, normalize=True)
# Out:
# Divorced        0.10
# Married         0.46
# Never-married   0.41
# Separated       0.02
# Widowed         0.00
# Name: maritalstatus, dtype: float64

# %%
nls97.filter(like="gov").apply(pd.value_counts, normalize=True)
# Out:
#                    govprovidejobs  govpricecontrols  govhealthcare  \
# 1. Definitely                0.25              0.54           0.67
# 2. Probably                  0.34              0.33           0.27
# 3. Probably not              0.25              0.09           0.05
# 4. Definitely not            0.16              0.04           0.02
#
#                    govelderliving  govindhelp  govunemp  govincomediff  \
# 1. Definitely                0.70        0.43      0.22           0.32
# 2. Probably                  0.25        0.41      0.40           0.28
# 3. Probably not              0.04        0.12      0.26           0.23
# 4. Definitely not            0.01        0.04      0.12           0.16
#
#                    govcollegefinance  govdecenthousing  govprotectenvironment
# 1. Definitely                   0.73              0.44                   0.67
# 2. Probably                     0.23              0.43                   0.29
# 3. Probably not                 0.03              0.10                   0.03
# 4. Definitely not               0.01              0.02                   0.02

# %%
las_frecuencias = open("views/reporte.txt",'w')

# %%
for col in nls97.select_dtypes(include=["category"]):
    print(col,"****--------------------------****", "frequencies", nls97[col].value_counts(sort=False),
          "percentages", nls97[col].value_counts(sort=False, normalize=True), sep="\n\n",end="\n\n\n", file=las_frecuencias)

# %%
las_frecuencias.close()
